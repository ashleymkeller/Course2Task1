# %%
# import modules and pandas
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
# creat connection
db_connection_str = 'mysql+pymysql://deepanalytics:Sqltask1234!@34.73.222.197/deepanalytics'

# %%
# connect to MySQL instance
db_connection = create_engine(db_connection_str)

# %%
# extract into pandas
df = pd.read_sql('SELECT * FROM credit', con=db_connection)

# %%
# first look at the data
df.describe()
# Out:
#        MyUnknownColumn     X1      X2          X3     X4     X5     X6     X7  \
# count            30204  30204   30204       30204  30204  30204  30204  30204
# unique           30002     83       4           6      6     58     13     13
# top                 ID  50000  female  university      2     29      0      0
# freq                 2   3397   18217       14107  16088   1619  14828  15830
#
#            X8     X9  ...    X15    X16    X17    X18    X19    X20    X21  \
# count   30204  30204  ...  30204  30204  30204  30204  30204  30204  30204
# unique     13     13  ...  21550  21012  20606   7945   7901   7520   6939
# top         0      0  ...      0      0      0      0      0      0      0
# freq    15863  16566  ...   3218   3530   4045   5287   5437   6007   6450
#
#           X22    X23            Y
# count   30204  30204        30204
# unique   6899   6941            4
# top         0      0  not default
# freq     6744   7233        23519
#
# ...

# %%
# more information on the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30204 entries, 0 to 30203
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MyUnknownColumn  30204 non-null  object
#  1   X1               30204 non-null  object
#  2   X2               30204 non-null  object
#  3   X3               30204 non-null  object
#  4   X4               30204 non-null  object
#  5   X5               30204 non-null  object
#  6   X6               30204 non-null  object
#  7   X7               30204 non-null  object
#  8   X8               30204 non-null  object
#  9   X9               30204 non-null  object
#  10  X10              30204 non-null  object
#  11  X11              30204 non-null  object
#  12  X12              30204 non-null  object
#  13  X13              30204 non-null  object
#  14  X14              30204 non-null  object
#  15  X15              30204 non-null  object
# ...

# %%
# save as csv to look at the data 
# index false because starting with 0 is driving me crazy
df.to_csv('CreditOneData.csv', index=False)

# %%
#data back in to the notebook
#first 202 rows are the duplicates and 203 is the header with x's
credit = pd.read_csv('CreditOneData.csv', header=204)

# %%
# now what does it look like
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
# describe data
credit.describe()
# Out:
#                  ID       LIMIT_BAL      MARRIAGE           AGE         PAY_0  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.551867     35.485500     -0.016700
# std     8660.398374   129747.661567      0.521970      9.217904      1.123802
# min        1.000000    10000.000000      0.000000     21.000000     -2.000000
# 25%     7500.750000    50000.000000      1.000000     28.000000     -1.000000
# 50%    15000.500000   140000.000000      2.000000     34.000000      0.000000
# 75%    22500.250000   240000.000000      2.000000     41.000000      0.000000
# max    30000.000000  1000000.000000      3.000000     79.000000      8.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.133767     -0.166200     -0.220667     -0.266200     -0.291100
# ...

# %%
# check for missing values
print(credit.isnull().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# check to see what datatypes are
credit.dtypes
# Out:
# ID                             int64
# LIMIT_BAL                      int64
# SEX                           object
# EDUCATION                     object
# MARRIAGE                       int64
# AGE                            int64
# PAY_0                          int64
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month    object
# dtype: object

# %%
# check what is not a number NaN in an entire dataframe
credit.isnull().values.any()
# Out:
# False

# %%
# trying some other functions
credit.tail()
# Out:
#           ID  LIMIT_BAL   SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 29995  29996     220000  male  high school         1   39      0      0
# 29996  29997     150000  male  high school         2   43     -1     -1
# 29997  29998      30000  male   university         2   37      4      3
# 29998  29999      80000  male  high school         1   41      1     -1
# 29999  30000      50000  male   university         1   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0      0  ...      88004      31237      15980      8500     20000
# 29996     -1     -1  ...       8979       5190          0      1837      3526
# 29997      2     -1  ...      20878      20582      19357         0         0
# 29998      0      0  ...      52774      11855      48944     85900      3409
# 29999      0      0  ...      36535      32428      15313      2078      1800
#
# ...
